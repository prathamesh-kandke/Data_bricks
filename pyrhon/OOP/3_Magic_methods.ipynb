# %% [markdown]
# ## Magic methods / Dunder methods :

# %%
class num:
    def __init__(self,n):
        self.n = n
    def __add__(self, other):
        return self.n + other.n
    def __sub__(self, other):
        return self.n - other.n
    def __mul__(self, other):
        return self.n * other.n
    def __truediv__(self, other):
        return self.n / other.n

# %%
n1=num(20)
n2=num(50)

# %%
n1+n2
# Out:
# 70

# %%
n2-n1
# Out:
# 30

# %%
n1*n2
# Out:
# 1000

# %%
n1/n2
# Out:
# 0.4

# %% [markdown]
# ### Comparison :
#     __gt__ (greter than)
#     __ge__ (greter than equal to)
#     __lt__ (less than)
#     __le__ (less than equal to)
#     __eq__ (equal to)

# %%
class num:
    def __init__(self,number):
        self.number=number
    def __gt__(self, other):
        return self.number > other.number
    def __ge__(self, other):
        return self.number >= other.number
    def __lt__(self, other):
        return self.number < other.number
    def __le__(self, other):
        return  self.number <= other.number
    def __eq__(self, other):
        return self.number == other.number
    def __ne__(self, other):
        return self.number != other.number

# %%
num1=num(10)
num2=num(20)

# %%
num1 > num2
# Out:
# False

# %%
num1 >= num2
# Out:
# False

# %%
num1 < num2, num1<=num2, num1 == num2, num1!=num2
# Out:
# (True, True, False, True)

# %%
# create the circle class with radius attribute
# create the area method inside circle to calculate area
# create the perimeter method inside the class to calculate the perimeter of cirlce

class circle():
    def __init__(self):
        pass
    def area_circle(self, r):
        total = 3.14*r*r
        print(f'Area of circle is {total}')
        #return total
    def perimeter(self,r):
        total = 2*3.14*r
        print(f'Perimeter of circle is {total}')
        return total

# %%
c1=circle()

# %%
c1.perimeter(3)
# Out:
# Perimeter of circle is 18.84
# 18.84

# %%
c1.area_circle(2)
# Out:
# Area of circle is 12.56
