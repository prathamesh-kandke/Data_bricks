# %% [markdown]
# ## Web Scrapping
# - to pull data from web pages
# - process of extracting data from websites
# - libraries
#     - beautifulSoup
#     - pattern
#     - html5
#     - request

# %% [markdown]
# - Step 1 - install lib and import
# - Step 2 - get html content
# - Step 3 - parsing .. to breakdown html content in simple form
# - Step 4 - tree traversal

# %%
# Step 1 - install lib and import
from bs4 import BeautifulSoup
import requests
import pandas as pd
import html

# %%
# Step 2 - get html content
url="https://en.wikipedia.org/wiki/World_War_II"

# %%
req=requests.get(url)
req

# %%
html_content=req.content

# %%
html_content

# %%
# Step 3 - parsing
soup=BeautifulSoup(html_content, 'html.parser')

# %%
soup

# %%
# Step 4 - Tree Traversal
soup.title.text

# %%
all_text=soup.text
all_text
# Out:
# '\n\n\n\nWorld War II - Wikipedia\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nJump to content\n\n\n\n\n\n\n\nMain menu\n\n\n\n\n\nMain menu\nmove to sidebar\nhide\n\n\n\n\t\tNavigation\n\t\n\n\nMain pageContentsCurrent eventsRandom articleAbout WikipediaContact us\n\n\n\n\n\n\t\tContribute\n\t\n\n\nHelpLearn to editCommunity portalRecent changesUpload file\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\nSearch\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAppearance\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nDonate\n\nCreate account\n\nLog in\n\n\n\n\n\n\n\n\nPersonal tools\n\n\n\n\n\nDonate Create account Log in\n\n\n\n\n\n\t\tPages for logged out editors learn more\n\n\n\nContributionsTalk\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContents\nmove to sidebar\nhide\n\n\n\n\n(Top)\n\n\n\n\n\n1\nStart and end dates\n\n\n\n\n\n\n\n\n2\nBackground\n\n\n\n\nToggle Background subsection\n\n\n\n\n\n2.1\nAftermath of World War I\n\n\n\n\n\n\
# ...

# %%
# all paragraph
list1=soup.find_all('p')

# %%
for i in list1:
    print(i.text)
# Out:
# Asia-Pacific
#
# Mediterranean and Middle East
#
# Other campaigns
#
# Coups
#
# World War II[b] or the Second World War (1 September 1939 – 2 September 1945) was a global conflict between two coalitions: the Allies and the Axis powers. Nearly all of the world's countries participated, with many nations mobilising all resources in pursuit of total war. Tanks and aircraft played major roles, enabling the strategic bombing of cities and delivery of the first and only nuclear weapons ever used in war. World War II was the deadliest conflict in history, resulting in 70 to 85 million deaths, more than half of which were civilians. Millions died in genocides, including the Holocaust, and by massacres, starvation, and disease. After the Allied victory, Germany, Austria, Japan, and Korea were occupied, and German and Japanese leaders were tried for war crimes.
#
# ...

# %%
# anchor tags
links=soup.find_all('a')

# %%
for i in links:
    print(i.get('href'))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Main_Page
# /wiki/Special:Search
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=World+War+II
# /w/index.php?title=Special:UserLogin&returnto=World+War+II
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=World+War+II
# /w/index.php?title=Special:UserLogin&returnto=World+War+II
# /wiki/Help:Introduction
# /wiki/Special:MyContributions
# /wiki/Special:MyTalk
# #
# #Start_and_end_dates
# #Background
# #Aftermath_of_World_War_I
# ...

# %%
ww2_content=soup.find_all('div')
for i in ww2_content:
    print(i.text)
# Out:
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Appearance
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
#
#
#
# Personal tools
#
#
#
#
#
# Donate Create account Log in
#
#
#
#
#
# 		Pages for logged out editors learn more
#
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
#
# 		Contribute
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# ...

# %%
ww2_content=soup.find_all('div', class_='vector-menu-content')
for i in ww2_content:
    print(i.text)
# Out:
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact us
#
#
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Donate
#
# Create account
#
# Log in
#
#
#
#
#
# Donate Create account Log in
#
#
#
#
# ContributionsTalk
#
#
#
#
# ...

# %%
for i in soup.find_all('p'):
    print(i)
# Out:
# <p class="mw-empty-elt">
# </p>
# <p><b><a href="/wiki/Pacific_War" title="Pacific War">Asia-Pacific</a></b>
# </p>
# <p><b><a href="/wiki/Mediterranean_and_Middle_East_theatre_of_World_War_II" title="Mediterranean and Middle East theatre of World War II">Mediterranean and Middle East</a></b>
# </p>
# <p><b>Other campaigns</b>
# </p>
# <p><b>Coups</b>
# </p>
# ...

# %%
import csv
f=csv.writer(open('dataprocessing.csv', 'w'))
f.writerows(['Title'])
f.writerows([soup.title.text])

# %%
# tables
overview=soup.find_all('table', class_='infobox vevent')
for z in overview:
    print(z.text)
# Out:
# World War IIFrom top to bottom, left to right:
# German Stuka dive bombers on the Eastern Front, 1943
# British Matilda II tanks during the North African campaign, 1941
# U.S. atomic bombing of Nagasaki in Japan, 1945
# Soviet troops at the Battle of Stalingrad, 1943
# Soviet soldier raising a flag over the Reichstag after the Battle of Berlin, 1945
# U.S. warships in Lingayen Gulf in the Philippines, 1945
# Date1 September 1939 – 2 September 1945[a]  (6 years, 1 day)LocationGlobal; primarily in Europe and the Asia-PacificResult
# Allied victoryParticipants
# Allies
# AxisCommanders and leaders
# Main Allied leaders:
#  Joseph Stalin
#  Franklin D. Roosevelt
#  Winston Churchill
#  Chiang Kai-shek
#
# Main Axis leaders:
#  Adolf Hitler
#  Hirohito
#  Benito Mussolini
# Casualties and losses
#
# Military dead:
# Over 16,000,000
# Civilian dead:
# Over 45,000,000
# Total dead:
# Over 61,000,000
# (1937–1945)
# ...further details
#
#
# Military dead:
# Over 8,000,000
# Civilian dead:
# ...

# %%
# www.wunderground.com
url="https://www.wunderground.com/weather/in/pune"

# %%
req=requests.get(url)
req
# Out:
# <Response [200]>

# %%
html_content=req.content
html_content
# Out:
# b'<!DOCTYPE html><html lang="en" itemscope="" itemtype="http://schema.org/Organization" prefix="og: http://ogp.me/ns#"><head itemscope="" itemtype="http://schema.org/WebSite">\n  <meta charset="utf-8">\n  <title>Pune, India Weather Conditions | Weather Underground</title>\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n  <link rel="dns-prefetch" href="//widgets.outbrain.com">\n  <link rel="dns-prefetch" href="//odb.outbrain.com">\n  <link rel="dns-prefetch" href="//c.amazon-adsystem.com">\n  <link rel="dns-prefetch" href="//s.amazon-adsystem.com">\n  <link rel="dns-prefetch" href="//aax.amazon-adsystem.com">\n  <link rel="dns-prefetch" href="//partner.googleadservices.com">\n  <link rel="dns-prefetch" href="//tpc.googlesyndication.com">\n  <link rel="dns-prefetch" href="//pagead2.googlesyndication.com">\n  <link rel="dns-prefetch" href="//h.nexac.com">\n  <link rel="dns-prefetch" href="//js-sec
# ...

# %%
soup=BeautifulSoup(req.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/Organization" lang="en" prefix="og: http://ogp.me/ns#"><head itemscope="" itemtype="http://schema.org/WebSite">
# <meta charset="utf-8"/>
# <title>Pune, India Weather Conditions | Weather Underground</title>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="//widgets.outbrain.com" rel="dns-prefetch"/>
# <link href="//odb.outbrain.com" rel="dns-prefetch"/>
# <link href="//c.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//s.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//aax.amazon-adsystem.com" rel="dns-prefetch"/>
# <link href="//partner.googleadservices.com" rel="dns-prefetch"/>
# <link href="//tpc.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//pagead2.googlesyndication.com" rel="dns-prefetch"/>
# <link href="//h.nexac.com" rel="dns-prefetch"/>
# ...

# %%
# URL for a specific location (replace with your city)
url = "https://www.wunderground.com/weather/in/pune"

# Set headers to mimic a real browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# Send GET request
response = requests.get(url, headers=headers)

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Find temperature (adjust selector as needed)
temperature = soup.find("span", class_="wu-value").text

print(f"Current Temperature in Pune: {temperature}°C")
# Out:
# Current Temperature in Pune: 46°C

# %% [markdown]
# ## Selenium
# Selenium is a popular Python module used for automating web browsers. It allows developers to control web browsers programmatically, enabling tasks such as web scraping, automated testing, and web application interaction. Selenium supports various web browsers, including Chrome, Firefox, Safari, and Edge, making it a versatile tool for browser automation.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# Set up Selenium
options = webdriver.ChromeOptions()
options.add_argument("--headless")  # Run in headless mode

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Open Weather Underground page
driver.get("https://www.wunderground.com/weather/in/pune")

# Wait for page to load
driver.implicitly_wait(10)

# Extract temperature (adjust selector as needed)
temperature = driver.find_element(By.CLASS_NAME, "wu-value").text

print(f"Current Temperature in Pune: {temperature}°C")

# Close driver
driver.quit()
# Out:
# Current Temperature in Pune: 42°C

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.imdb.com/chart/top'
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    soup = BeautifulSoup(response.text, "html.parser")
    print(soup.prettify())  # Check the HTML structure
else:
    print(f"Error: {response.status_code}")
# Out:
# <!DOCTYPE html>
# <html lang="en-US" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width" name="viewport"/>
#   <script>
#    if(typeof uet === 'function'){ uet('bb', 'LoadTitle', {wb: 1}); }
#   </script>
#   <script>
#    window.addEventListener('load', (event) => {
#         if (typeof window.csa !== 'undefined' && typeof window.csa === 'function') {
#             var csaLatencyPlugin = window.csa('Content', {
#                 element: {
#                     slotId: 'LoadTitle',
#                     type: 'service-call'
#                 }
#             });
#             csaLatencyPlugin('mark', 'clickToBodyBegin', 1739276954392);
#         }
#     })
#   </script>
#   <title>
#    IMDb Top 250 Movies
#   </title>
#   <meta content="As rated by regular IMDb voters." data-id="main" name="description"/>
#   <meta content="max-image-preview:large" name="robots"/>
# ...

# %%
import requests
import json
from bs4 import BeautifulSoup

# URL of IMDb Top 250 Movies
url = "https://www.imdb.com/chart/top"

# Headers to mimic a real browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
}

# Request IMDb page
response = requests.get(url, headers=headers)

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Find JSON-LD script containing movie details
json_script = soup.find("script", type="application/ld+json")

if json_script:
    # Parse JSON data
    data = json.loads(json_script.string)

    # Extract movies and ratings
    if "itemListElement" in data:
        for movie in data["itemListElement"]:
            name = movie["item"]["name"]
            rating = movie["item"]["aggregateRating"]["ratingValue"]
            print(f"{name}: {rating}")
else:
    print("Could not find JSON-LD script")
# Out:
# The Shawshank Redemption: 9.3
# The Godfather: 9.2
# The Dark Knight: 9
# The Godfather Part II: 9
# 12 Angry Men: 9
# The Lord of the Rings: The Return of the King: 9
# Schindler&apos;s List: 9
# Pulp Fiction: 8.9
# The Lord of the Rings: The Fellowship of the Ring: 8.9
# Il buono, il brutto, il cattivo: 8.8
# Forrest Gump: 8.8
# The Lord of the Rings: The Two Towers: 8.8
# Fight Club: 8.8
# Inception: 8.8
# Star Wars: Episode V - The Empire Strikes Back: 8.7
# The Matrix: 8.7
# GoodFellas: 8.7
# One Flew Over the Cuckoo&apos;s Nest: 8.7
# Interstellar: 8.7
# Se7en: 8.6
# It&apos;s a Wonderful Life: 8.6
# Shichinin no samurai: 8.6
# The Silence of the Lambs: 8.6
# Saving Private Ryan: 8.6
# Cidade de Deus: 8.6
# The Green Mile: 8.6
# La vita è bella: 8.6
# Terminator 2: Judgment Day: 8.6
# Star Wars: 8.6
# Back to the Future: 8.5
# Sen to Chihiro no kamikakushi: 8.6
# The Pianist: 8.5
# Gladiator: 8.5
# Gisaengchung: 8.5
# Psycho: 8.5
# The Lion King: 8.5
# Hotaru no haka: 8.5
# ...

# %%
import requests
import json
from bs4 import BeautifulSoup

# IMDb Top 250 Movies URL
url = "https://www.imdb.com/chart/top"

# Headers to mimic a real browser
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
}

# Request IMDb page
response = requests.get(url, headers=headers)

# Parse HTML
soup = BeautifulSoup(response.text, "html.parser")

# Find JSON-LD script containing movie details
json_script = soup.find("script", type="application/ld+json")

if json_script:
    # Parse JSON data
    data = json.loads(json_script.string)

    # Extract movies and ratings
    if "itemListElement" in data:
        for movie in data["itemListElement"]:
            name = movie["item"]["name"]
            rating = movie["item"]["aggregateRating"]["ratingValue"]
            image = movie["item"]["image"]
            print(f"{name}: {rating}\nPoster: {image}\n")
else:
    print("Could not find JSON-LD script")
# Out:
# The Shawshank Redemption: 9.3
# Poster: https://m.media-amazon.com/images/M/MV5BMDAyY2FhYjctNDc5OS00MDNlLThiMGUtY2UxYWVkNGY2ZjljXkEyXkFqcGc@._V1_.jpg
#
# The Godfather: 9.2
# Poster: https://m.media-amazon.com/images/M/MV5BZTg0ZjcwOGUtZGIyOS00YTFlLWI5ZWQtYjA2NDgxMWJhZmNjXkEyXkFqcGc@._V1_.jpg
#
# The Dark Knight: 9
# Poster: https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_.jpg
#
# The Godfather Part II: 9
# Poster: https://m.media-amazon.com/images/M/MV5BNDNkZDI5ODctYmUzYy00MDhkLTg5OWMtYzdhMjU1NTRlNjUzXkEyXkFqcGc@._V1_.jpg
#
# 12 Angry Men: 9
# Poster: https://m.media-amazon.com/images/M/MV5BYjE4NzdmOTYtYjc5Yi00YzBiLWEzNDEtNTgxZGQ2MWVkN2NiXkEyXkFqcGc@._V1_.jpg
#
# The Lord of the Rings: The Return of the King: 9
# Poster: https://m.media-amazon.com/images/M/MV5BMTZkMjBjNWMtZGI5OC00MGU0LTk4ZTItODg2NWM3NTVmNWQ4XkEyXkFqcGc@._V1_.jpg
#
# Schindler&apos;s List: 9
# ...

# %%
from IPython.display import display, Image

for movie in data["itemListElement"]:
    name = movie["item"]["name"]
    rating = movie["item"]["aggregateRating"]["ratingValue"]
    image_url = movie["item"]["image"]

    print(f"{name}: {rating}")
    display(Image(url=image_url))
# Out:
# The Shawshank Redemption: 9.3
# <img src="https://m.media-amazon.com/images/M/MV5BMDAyY2FhYjctNDc5OS00MDNlLThiMGUtY2UxYWVkNGY2ZjljXkEyXkFqcGc@._V1_.jpg"/>
# The Godfather: 9.2
# <img src="https://m.media-amazon.com/images/M/MV5BZTg0ZjcwOGUtZGIyOS00YTFlLWI5ZWQtYjA2NDgxMWJhZmNjXkEyXkFqcGc@._V1_.jpg"/>
# The Dark Knight: 9
# <img src="https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_.jpg"/>
# The Godfather Part II: 9
# <img src="https://m.media-amazon.com/images/M/MV5BNDNkZDI5ODctYmUzYy00MDhkLTg5OWMtYzdhMjU1NTRlNjUzXkEyXkFqcGc@._V1_.jpg"/>
# 12 Angry Men: 9
# <img src="https://m.media-amazon.com/images/M/MV5BYjE4NzdmOTYtYjc5Yi00YzBiLWEzNDEtNTgxZGQ2MWVkN2NiXkEyXkFqcGc@._V1_.jpg"/>
# The Lord of the Rings: The Return of the King: 9
# <img src="https://m.media-amazon.com/images/M/MV5BMTZkMjBjNWMtZGI5OC00MGU0LTk4ZTItODg2NWM3NTVmNWQ4XkEyXkFqcGc@._V1_.jpg"/>
# Schindler&apos;s List: 9
# ...
